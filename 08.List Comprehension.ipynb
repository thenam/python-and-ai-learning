# %% [markdown]
# # Bài tập

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
stop_words = ["I", "love", "and", "to"]
input_str = "I love AI and listen to music"

# %%
result = [item for item in input_str.split() if item not in stop_words]
print(result)
# Out:
# ['AI', 'listen', 'music']
